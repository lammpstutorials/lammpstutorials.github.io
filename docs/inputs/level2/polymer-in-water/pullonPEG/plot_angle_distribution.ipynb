# %%
import numpy as np
import sys, os, git
from matplotlib import pyplot as plt

# %%
current_path = os.getcwd()
git_repo = git.Repo(current_path, search_parent_directories=True)
git_path = git_repo.git.rev_parse("--show-toplevel")
sys.path.append(git_path+"/docs/inputs/shared-pyplot-files/")
from pyplot_parameters import colors, complete_panel, save_figure, set_boundaries
path_in_folder = current_path[len(git_path)+1:]
level = path_in_folder.split("/")[2][-1]
tutorial_name = path_in_folder.split("/")[3]
path_figures = "/docs/sphinx/source/tutorials/figures/level" + level + "/" + tutorial_name + "/"
print("level:" , level, "& tutorial name:", tutorial_name)
print("figures will be saved in", path_figures)
# Out:
# level: 2 & tutorial name: polymer-in-water
# figures will be saved in /docs/sphinx/source/tutorials/figures/level2/polymer-in-water/

# %%
_, r, _, bond_H2O_free = np.loadtxt("bond_PEG_free.dat", skiprows=4).T
_, r, _, bond_H2O_pull = np.loadtxt("bond_PEG_pull.dat", skiprows=4).T

# %%
plt.plot(r, bond_H2O_free)
plt.plot(r, bond_H2O_pull)

# %%
_, r, _, bond_H2O_free = np.loadtxt("bond_H2O_free.dat", skiprows=4).T
_, r, _, bond_H2O_pull = np.loadtxt("bond_H2O_pull.dat", skiprows=4).T

# %%
plt.plot(r, bond_H2O_free)
plt.plot(r, bond_H2O_pull)

# %%
_, r, _, bond_H2O_free = np.loadtxt("dihedral_PEG_free.dat", skiprows=4).T
_, r, _, bond_H2O_pull = np.loadtxt("dihedral_PEG_pull.dat", skiprows=4).T

# %%
plt.plot(r, bond_H2O_free)
plt.plot(r, bond_H2O_pull)

# %%
_, r, _, bond_H2O_free = np.loadtxt("angle_H2O_free.dat", skiprows=4).T
_, r, _, bond_H2O_pull = np.loadtxt("angle_H2O_pull.dat", skiprows=4).T

# %%
plt.plot(r, bond_H2O_free)
plt.plot(r, bond_H2O_pull)

# %%
filename = "test"
for mode, mygray in zip(['light', 'dark'], [colors["lightgray"], colors["darkgray"]]):    
    fig = plt.figure(figsize=(18,6))
    ax, n, l_tot, c_tot = [], 0, 1, 1
    n += 1
    ax.append(plt.subplot(l_tot, c_tot, n))
    x = np.arange(0, 45, 0.1)
    ax[-1].plot(x*0 + 30, x, '--', color=mygray, linewidth=3.5)
    ax[-1].plot(time, distance, color=colors["myblue"], linewidth=3.5)
    complete_panel(ax[-1], r'$t$ (ps)', r'end-to-end distance (nm)', legend=False, axis_color=mygray)
    set_boundaries(plt, x_ticks=np.arange(0, 70, 10), y_ticks=np.arange(10, 45, 5),
                   x_boundaries=(-2, 62), y_boundaries=(10, 40))
    #save_figure(fig, mode, git_path, path_figures, filename)
