# %%
import numpy as np
import sys, os, git
from matplotlib import pyplot as plt

# %%
current_path = os.getcwd()
git_repo = git.Repo(current_path, search_parent_directories=True)
git_path = git_repo.git.rev_parse("--show-toplevel")
path_in_folder = current_path[len(git_path)+1:]
level = path_in_folder.split("/")[-2]
tutorial_name = path_in_folder.split("/")[-1]
print("level:" , level, "& tutorial name:", tutorial_name)
sys.path.append(git_path + "/docs/sphinx/source/tutorials/figures/pyplot-perso/")
from functions import complete_panel, save_figure, set_boundaries, \
                      add_subplotlabels, set_boundaries, prepare_figure
from color_series1 import colors
path_figures = current_path[len(git_path):] + '/'
data_path = git_path + "/docs/lammpstutorials-inputs/" + level + "/" + tutorial_name + "/BiasedSampling/"
print("data path: ", data_path)
# Out:
# level: level3 & tutorial name: free-energy-calculation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 sys.path.append(git_path + "/docs/sphinx/source/tutorials/figures/pyplot-perso/")
#       9 from functions import complete_panel, save_figure, set_boundaries, \
#      10                       add_subplotlabels, set_boundaries, prepare_figure
# ---> 11 from color_series1 import colors
#      12 path_figures = current_path[len(git_path):] + '/'
#      13 data_path = git_path + "/docs/lammpstutorials-inputs/" + level + "/" + tutorial_name + "/BiasedSampling/"
#
# File ~/Git/LAMMPS/tutorials/docs/sphinx/source/tutorials/figures/pyplot-perso/color_series1.py:16
#       1 import numpy as np
#       3 colors = {
#       4   "myblue": [0.0, 0.588, 0.694],
#       5   "mydarkblue": [0.008, 0.294, 0.478],
#       6   "mycyan": [0.267, 0.718, 0.761],
#       7   "myorange": [1.0, 0.682, 0.286],
#       8   "mylightgray": [0.1, 0.1, 0.1],
#       9   "mygray": [0.5, 0.5, 0.5],
#      10   "mydarkgray": [0.9, 0.9, 0.9],
#      11   "myblueANR": [0.224, 0.467, 0.878],
#      12   "myredANR": [0.867, 0.349, 0.384],
#      13   "blue1livecom": [0.153, 0.231, 0.606],
#      14   "blue2livecom": [0.033, 0.7, 0.97],
#      15   "graylivecom": [0.427, 0.431, 0.439],
# ---> 16   "neoncyan": [0, 254, 252]/255,
#      17   "skobeloffgreen": [0, 116, 116]/255,
#      18   "tealblue": [54, 117, 136]/255,
#      19   "midnightgreen": [0, 73, 83]/255,
#      20 }
#      22 def mygradient(N, color1, color2, final_value=False):
#      23     """Generate a color gradient from color1 to color2"""
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
PMF = np.loadtxt(data_path + 'PMF.dat')
xmd, PMF, _, _, _ = PMF.T

# %%
sigma = 3.405 # Angstrom
epsilon = 0.238 # Kcal/mol
U0 = 10*epsilon # Kcal/mol
delta = 0.5 # Angstrom
x0 = 5.0 # Angstrom
x = np.linspace(-25, 25, 50000)  # Angstrom
U = U0 * (np.arctan((x + x0) / delta) - np.arctan((x - x0) / delta))
F = (U0/delta)/(((x - x0)**2)/delta**2 + 1) - (U0/delta)/(((x + x0)**2)/delta**2 + 1)

# %%
filename = "freeenergy"
for mode, mygray in zip(['light', 'dark'], [colors["mylightgray"], colors["mydarkgray"]]):    
    fig = prepare_figure(mode, transparency = True, desired_figsize=(18,6))
    ax, n, l_tot, c_tot = [], 0, 1, 1
    n += 1
    ax.append(plt.subplot(l_tot, c_tot, n))
    ax[-1].plot(x, U, color=mygray, linewidth=3)
    ax[-1].plot(xmd, PMF, color=colors["myblue"], linewidth=3)
    complete_panel(ax[-1], r'$x ~ \textrm{(Å)}$', r'$U ~ \textrm{(kcal/mol)}$',
                legend=False, axis_color=mygray, xpad=8)
    set_boundaries(plt, x_ticks=np.arange(-25, 30, 5), x_boundaries=(-26, 26))
    save_figure(plt, fig, mode, git_path, path_figures, filename)

# %%
filename = "freeenergy-article"
mode = 'light'
mygray = colors["mylightgray"]
fig = prepare_figure(mode, transparency = False, desired_figsize=(12,5), serif=False)
ax, n, l_tot, c_tot = [], 0, 1, 1
n += 1
ax.append(plt.subplot(l_tot, c_tot, n))
ax[-1].plot(xmd, PMF, 'o', color=colors["neoncyan"], markersize=12, linewidth=3, label=r"\textrm{Measured}")
ax[-1].plot(x, U, color=colors["mylightgray"], linewidth=3, label=r"\textrm{Imposed}")
complete_panel(ax[-1], r'$x ~ \textrm{(Å)}$', r'$U ~ \textrm{(kcal/mol)}$',
            legend=True, axis_color=mygray, xpad=8)
set_boundaries(plt, x_ticks=np.arange(-25, 30, 10), x_boundaries=(-27, 27), y_ticks=np.arange(0, 9, 2),  y_boundaries=(-1, 9))
save_figure(plt, fig, mode, git_path, path_figures, filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 filename = "freeenergy-article"
#       2 mode = 'light'
# ----> 3 mygray = colors["mylightgray"]
#       4 fig = prepare_figure(mode, transparency = False, desired_figsize=(12,5), serif=False)
#       5 ax, n, l_tot, c_tot = [], 0, 1, 1
#
# NameError: name 'colors' is not defined
