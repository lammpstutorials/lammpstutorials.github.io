# %%
import numpy as np
import sys, os, git, lammps_logfile
from matplotlib import pyplot as plt

# %%
current_path = os.getcwd()
git_repo = git.Repo(current_path, search_parent_directories=True)
git_path = git_repo.git.rev_parse("--show-toplevel")
path_in_folder = current_path[len(git_path)+1:]
level = path_in_folder.split("/")[-2]
tutorial_name = path_in_folder.split("/")[-1]
print("level:" , level, "& tutorial name:", tutorial_name)
sys.path.append(git_path + "/docs/sphinx/source/tutorials/figures/pyplot-perso/")
from functions import complete_panel, save_figure, set_boundaries, \
                      add_subplotlabels, set_boundaries, prepare_figure
from color_series1 import colors
path_figures = current_path[len(git_path):] + '/'
data_path = git_path + "/docs/lammpstutorials-inputs/" + level + "/" + tutorial_name + "/Deform/"
print("data path: ", data_path)
# Out:
# level: level3 & tutorial name: reactive-silicon-dioxide
# data path:  /home/simon/Git/LAMMPS/tutorials/docs/lammpstutorials-inputs/level3/reactive-silicon-dioxide/Deform/

# %%
log = lammps_logfile.File(data_path + "log.lammps")
step = log.get("Step")
temp = log.get("Temp")
qSi = log.get("v_qSi")
qO = log.get("v_qO")
Volume = log.get("Volume")
timestep = 0.5
time = step*timestep

# %%
filename = "deformed-charge"
for mode, mygray in zip(['light', 'dark'], [colors["mylightgray"], colors["mydarkgray"]]):    
    fig = prepare_figure(mode, transparency = True, desired_figsize=(18,9))
    ax, n, l_tot, c_tot = [], 0, 2, 1
    n += 1
    ax.append(plt.subplot(l_tot, c_tot, n))
    ax[-1].plot(time/1000, qSi, color=colors["myblue"], linewidth=3)
    complete_panel(ax[-1], None, r'$q_\textrm{Si}$ (e)', legend=False, axis_color=mygray, xpad=8)
    x = np.linspace(1.45, 1.9)
    ax[-1].plot(x*0+2.5, x, '--', color=mygray, linewidth=3)
    x = np.linspace(0, 15)
    ax[-1].plot(x, x*0+1.875, '.', color=colors["myblue"])
    set_boundaries(plt, x_ticks=np.arange(0, 16, 2.5), y_ticks=np.arange(1.5, 2, 0.1))
    n += 1
    ax.append(plt.subplot(l_tot, c_tot, n))
    ax[-1].plot(time/1000, qO, color=colors["myorange"], linewidth=3)
    complete_panel(ax[-1], r'$t ~ \mathrm{(ps)}$', r'$q_\textrm{O}$ (e)', legend=False, axis_color=mygray, xpad=8)
    x = np.linspace(-1, -0.7)
    ax[-1].plot(x*0+2.5, x, '--', color=mygray, linewidth=3)
    x = np.linspace(0, 15)
    ax[-1].plot(x, x*0-0.934, '.', color=colors["myorange"])
    set_boundaries(plt, x_ticks=np.arange(0, 16, 2.5), y_ticks=np.arange(-1, -0.7, 0.1))
    add_subplotlabels(fig, ax, [r"$\mathrm{a}$", r"$\mathrm{b}$"], color=mygray)
    save_figure(plt, fig, mode, git_path, path_figures, filename)

# %%
filename = "deformed-temperature"
for mode, mygray in zip(['light', 'dark'], [colors["mylightgray"], colors["mydarkgray"]]):    
    fig = prepare_figure(mode, transparency = True, desired_figsize=(18,5))
    ax, n, l_tot, c_tot = [], 0, 1, 1
    n += 1
    ax.append(plt.subplot(l_tot, c_tot, n))
    ax[-1].plot(time/1000, temp, color=colors["myblue"], linewidth=3)
    complete_panel(ax[-1], r'$t ~ \mathrm{(ps)}$', r'$T ~ \mathrm{(K)}$',
                    legend=False, axis_color=mygray, xpad=8)
    set_boundaries(plt, x_ticks=np.arange(0, 16, 2.5), y_ticks=np.arange(0, 1100, 200))
    # add_subplotlabels(fig, ax, ["a", "b"], color=mygray)
    save_figure(plt, fig, mode, git_path, path_figures, filename)

# %%
filename = "deformed-charge-article"
mode = 'light'
mygray = colors["mylightgray"]
fig = prepare_figure(mode, transparency = False, desired_figsize=(12,8), serif=False)
ax, n, l_tot, c_tot = [], 0, 2, 1
n += 1
ax.append(plt.subplot(l_tot, c_tot, n))
ax[-1].plot(time[::30]/1000, qSi[::30], 'o', color=colors["unisoncyan"], markersize=12, linewidth=3)
complete_panel(ax[-1], None, r'$q_\mathrm{Si}$ (e)', legend=False, axis_color=mygray, xpad=8)
x = np.linspace(1.45, 1.9)
ax[-1].plot(x*0+2.5, x, '--', color=mygray, linewidth=3)
x = np.linspace(0, 15)
ax[-1].plot(x, x*0+1.875, '.', color=colors["unisoncyan"])
set_boundaries(plt, x_ticks=np.arange(0, 16, 2.5), y_ticks=np.arange(1.5, 2, 0.1))
n += 1
ax.append(plt.subplot(l_tot, c_tot, n))
ax[-1].plot(time[::30]/1000, qO[::30], 'o', color=colors["myorange"], markersize=12, linewidth=3)
complete_panel(ax[-1], r'$t ~ \mathrm{(ps)}$', r'$q_\mathrm{O}$ (e)', legend=False, axis_color=mygray, xpad=8)
x = np.linspace(-1, -0.7)
ax[-1].plot(x*0+2.5, x, '--', color=mygray, linewidth=3)
x = np.linspace(0, 15)
ax[-1].plot(x, x*0-0.934, '.', color=colors["myorange"])
set_boundaries(plt, x_ticks=np.arange(0, 16, 2.5), y_ticks=np.arange(-1, -0.7, 0.1))
add_subplotlabels(fig, ax, [r"$\mathrm{a}$", r"$\mathrm{b}$"], color=mygray)
save_figure(plt, fig, mode, git_path, path_figures, filename)

# %%
filename = "temperature-article"
mode = 'light'
mygray = colors["mylightgray"]
fig = prepare_figure(mode, transparency = False, desired_figsize=(12,5), serif=False)
ax, n, l_tot, c_tot = [], 0, 1, 1
n += 1
ax.append(plt.subplot(l_tot, c_tot, n))
ax[-1].plot(time[::30]/1000, temp[::30], "o", color=colors["unisoncyan"], linewidth=3)
complete_panel(ax[-1], r'$t ~ \mathrm{(ps)}$', r'$T ~ \mathrm{(K)}$',
                legend=False, axis_color=mygray, xpad=8)
set_boundaries(plt, x_ticks=np.arange(0, 16, 2.5), y_ticks=np.arange(0, 1100, 200))
# add_subplotlabels(fig, ax, ["a", "b"], color=mygray)
save_figure(plt, fig, mode, git_path, path_figures, filename)
